# %% [markdown]
# #### Arithmetic Operators
#     - Add (+)
#     - Subtract (-)
#     - Multiply (*)
#     - Division
#     - Float Division (/)
#     - Floor Division (//)
#     - Power Exponent (**)
#     - Modulus (%)

# %%
print(5+5) #add
print(3-2) #sub
print(5*5) # multiply
# tamam operators without print function bi execute ho jata hy
# Out:
# 10
# 1
# 25

# %%
print(10/4) #float division (kabhi answer kafi detailed ya accurate chaye hota hy)
print(10//4) #floor division / int
# divide me answer davidant ka quotient ata hy
# Out:
# 2.5
# 2

# %%
4**3 # power or exponent
# Out:
# 64

# %%
10%4 # modulus me answer davidant ka
# Out:
# 2

# %% [markdown]
# #### Comparison / Relational Operators
#     (2 values ko compare karte hain)
#
#     - Greater than (>)
#     - Less than (<)
#     - Greater than & equal to (>=)
#     - Less than  & equal to (<=)
#     - double equal to (==)
#     - not equal to (!=)

# %%
print(12>10)
print(10>12)
# Out:
# True
# False

# %%
print(8<10)
print(10<8)
# Out:
# True
# False

# %%
print (10>=9)
print (10>=10)
print (9>=10)
# Out:
# True
# True
# False

# %%
print (10<=9)
print (10<=10)
print (9<=10)
# Out:
# False
# True
# True

# %%
print(10==11)
print(10==10)
# Out:
# False
# True

# %%
print(10!=11)
print(10!=10)
# Out:
# True
# False

# %% [markdown]
# #### Logical Operators
#     (Multiple Condistions me used hota hy)
#
#     - and
#     - or
#     - not

# %%
(10 > 10) or (20 > 100)
# Out:
# False

# %%
(10 > 10) or (200 > 100)  # or opeator ko True k lie aik bi true ml jy gi chahe star he my wo pori value ko true krdege
# Out:
# True

# %% [raw]
# Condition 1st OR Condition 2nd Result
# true          OR true          true
# true          OR false         true
# false         OR true          true
# false         OR false         false

# %%
(10 > 10) and (200 > 100) # and operator ko False k lie bi False ml jywo pori value ko fa;se krdege
# Out:
# False

# %%
(132 > 10) and (200 > 100) # and opeator ko True k lie dono value ka true hona lazmi hota hy
# Out:
# True

# %% [raw]
# Condition 1st And Condition 2nd Result
# true          And true          true
# true          And false         false
# false         And true          false
# false         And false         false

# %%
# hr aik valid value ka boolean (truthy) hota hy
print(bool (0))
print(bool(1))
print(bool("python"))
print(bool(""))
# Out:
# False
# True
# True
# False

# %%
2 and 5 # isne 5 execute is lie kia hy ka tamam value ko read kre k aik bi false value mil jae to complete false krde
# Out:
# 5

# %%
2 or 5 # isne 2 islie execute kia q k is ko start me hi true value mil gaye baqi bilfarz sb false bhi ho or ko sirf aik value true chaye
# Out:
# 2

# %% [markdown]
# #### if python statement
#     - x = a + 5 - b
#     - a and are = operands
#     - a + 5 - b is = expression
# #### isinstance
#     - value ki type bata hy k aya ye hy k ni (x,int/float/bool)
#     - jb k type function bhi value ki type bata hy directly type(x)
#
# #### Assignment Operator (=)
#     - x = 10
#     measn that value 10 assign to x

# %%
x = 1

# %%
print(isinstance(x,str))
print(isinstance(x,float))
print(isinstance(x,bool))
print(isinstance(x,int))
# Out:
# False
# False
# False
# True

# %%
d = 10.0

# %%
y = (d < 100.0) and isinstance (d,float)

# %%
y
# Out:
# True

# %% [markdown]
# #### Identity Operator:
#     is

# %%
x = 10 # x ko value pass ki
y = x # y ko reference pass kya - y ko value dene k bjae y me x ka address add krdia
# is se jo bi value ham x ko dege wo auto y me bi allocate ho jy gi

# %%
x is y
# Out:
# True

# %%
x # jo bi value ham x me change kry gy wo y me ajygi
# Out:
# 10

# %%
y is x
# Out:
# True

# %%
id(x) # or ye address hy jo ram me save hojata hy
# Out:
# 140706631689416

# %%
id(y)
# Out:
# 140706631689416

# %% [markdown]
# #### P E M D A S

# %%
1+2**3*4
# Out:
# 33
