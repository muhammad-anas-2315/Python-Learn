# %%
import shopping

# %%
shopping.shop
# Out:
# [{'item': 'flour', 'price': 100, 'inventory': 250},
#  {'item': 'sugar', 'price': 180, 'inventory': 500},
#  {'item': 'rice', 'price': 300, 'inventory': 500},
#  {'item': 'oil', 'price': 500, 'inventory': 1000},
#  {'item': 'ghee', 'price': 500, 'inventory': 500},
#  {'item': 'tea', 'price': 400, 'inventory': 100},
#  {'item': 'soap', 'price': 200, 'inventory': 50},
#  {'item': 'salt', 'price': 50, 'inventory': 100}]

# %%
shopping.shopping()
# Out:
# Enter the item you want to buy or (press "q" to exit) soap
# soap 200 ka hy
# Kitna Chaye? 2
# Enter the item you want to buy or (press "q" to exit) q
# Thank you for shopping
#
#         soap : 400.0
#
#
#     Total Amount: 400.0
#     Applied Discount: 0.0
#     Tax Applied: 0.0
#     Amount Payable: 400.0

# %%
import bank

# %%
bank.all_accounts
# Out:
# []

# %%
bank.open_account()
# Out:
# Welcome to Bank
# Enter account title:  nasirhussain
# Enter Cnic No.  1234
# Enter Contact No.  12345678900
# Initial Deposit:  1000
# Your account opened!
# Your account title is nasirhussain & Account no is 8307789

# %%
bank.balance_check(8307789)
# Out:
# your account balance is Rs: 1000

# %%
bank.cash_deposit(8307789,2000)
# Out:
# Amount deposited successfully

# %%
bank.balance_check(8307789)
# Out:
# your account balance is Rs: 3000

# %%
from bank import all_accounts

# %%
all_accounts
# Out:
# [{'title': 'nasirhussain',
#   'cnic': '1234',
#   'contact': '12345678900',
#   'balance': 3000,
#   'account_no': 8307789}]

# %%
from bank import cash_deposit, cash_withdraw

# %%
from bank import open_account as oa
